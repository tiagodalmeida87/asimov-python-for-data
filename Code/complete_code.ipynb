# %% [markdown]
# Primeiro Código

# %%
mensagem = "Olá mundo!"
print(mensagem)
# Out:
# Olá mundo!

# %%
nome = 'Tiago'
idade = 38
texto = f"Meu nome é {nome} e tenho {idade} anos."
print(texto)
# Out:
# Meu nome é Tiago e tenho 38 anos.

# %% [markdown]
# Carregando os Dados

# %%
caminho_dados = "/content/drive/MyDrive/AD/2025_Viagem.csv"

# %%
import pandas as pd

df_viagens = pd.read_csv(caminho_dados, encoding="Windows-1252", sep=";")
pd.set_option('display.max_columns', None)

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  20150776                 060767/25
# 1                                  20261730              000086/25-1C
# 2                                  20286869                 000002/25
# 3                                  20289421                 000001/25
# 4                                  20289650                 000004/25
# ...                                     ...                       ...
# 774485                           2025002373             Sem informaçã
# 774486                           2025002377             Sem informaçã
# 774487                           2025002380             Sem informaçã
# 774488                           2025002397             Sem informaçã
# 774489                           2025002398             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
df_viagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774490 entries, 0 to 774489
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  774490 non-null  int64
#  1   Número da Proposta (PCDP)            774490 non-null  object
#  2   Situação                             774490 non-null  object
#  3   Viagem Urgente                       774490 non-null  object
#  4   Justificativa Urgência Viagem        774228 non-null  object
#  5   Código do órgão superior             774490 non-null  int64
#  6   Nome do órgão superior               774490 non-null  object
#  7   Código órgão solicitante             774490 non-null  int64
#  8   Nome órgão solicitante               774490 non-null  object
#  9   CPF viajante                         605451 non-null  object
#  10  Nome                                 774490 non-null  object
# ...

# %%
df_viagens["Nome do órgão superior"]
# Out:
# 0                                      Ministério da Defesa
# 1                                    Ministério da Educação
# 2                                    Ministério da Educação
# 3                                      Ministério da Defesa
# 4                                      Ministério da Defesa
#                                 ...
# 774485    Banco Central do Brasil - Orçamento Fiscal e S...
# 774486    Banco Central do Brasil - Orçamento Fiscal e S...
# 774487    Banco Central do Brasil - Orçamento Fiscal e S...
# 774488    Banco Central do Brasil - Orçamento Fiscal e S...
# 774489    Banco Central do Brasil - Orçamento Fiscal e S...
# Name: Nome do órgão superior, Length: 774490, dtype: object

# %%
df_viagens["Valor diárias"]
# Out:
# 0            0,00
# 1            0,00
# 2            0,00
# 3            0,00
# 4            0,00
#            ...
# 774485    1154,55
# 774486    1154,55
# 774487    1249,55
# 774488    1021,14
# 774489     641,59
# Name: Valor diárias, Length: 774490, dtype: object

# %%
colunas = ["Nome", "Nome do órgão superior", "Valor diárias"]
df_viagens[colunas]
# Out:
#                                           Nome  \
# 0           PETERSON RODRIGUES DA SILVA SANTOS
# 1                        NAZIRA CORREIA CAMELY
# 2                          ALMIR MANOEL CUNICO
# 3               ROMULO FABIANO PACHECO RAVAZIO
# 4              ALFREDO DIAS DE OLIVEIRA JUNIOR
# ...                                        ...
# 774485                 AILTON DE AQUINO SANTOS
# 774486                      DIOGO ABRY GUILLEN
# 774487  MARIA DO P SOCORRO A CARDOSO DE CASTRO
# 774488                  BRUNO DE OLIVEIRA MAIA
# 774489        CARINE MOREIRA DE ALMEIDA BASTOS
#
#                                    Nome do órgão superior Valor diárias
# 0                                    Ministério da Defesa          0,00
# 1                                  Ministério da Educação          0,00
# 2                                  Ministério da Educação          0,00
# 3                                    Ministério da Defesa          0,00
# ...

# %%
df_viagens["Nome do órgão superior"].str.upper()
# Out:
# 0                                      MINISTÉRIO DA DEFESA
# 1                                    MINISTÉRIO DA EDUCAÇÃO
# 2                                    MINISTÉRIO DA EDUCAÇÃO
# 3                                      MINISTÉRIO DA DEFESA
# 4                                      MINISTÉRIO DA DEFESA
#                                 ...
# 774485    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 774486    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 774487    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 774488    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 774489    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# Name: Nome do órgão superior, Length: 774490, dtype: object

# %%
df_viagens["Nome do órgão superior"].str.upper().str.replace('MINISTÉRIO', 'MIN.')
# Out:
# 0                                            MIN. DA DEFESA
# 1                                          MIN. DA EDUCAÇÃO
# 2                                          MIN. DA EDUCAÇÃO
# 3                                            MIN. DA DEFESA
# 4                                            MIN. DA DEFESA
#                                 ...
# 774485    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 774486    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 774487    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 774488    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 774489    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# Name: Nome do órgão superior, Length: 774490, dtype: object

# %%
df_viagens[["Valor diárias", "Valor passagens"]]
# Out:
#        Valor diárias Valor passagens
# 0               0,00            0,00
# 1               0,00            0,00
# 2               0,00         2544,74
# 3               0,00         4329,72
# 4               0,00         7109,73
# ...              ...             ...
# 774485       1154,55         4507,09
# 774486       1154,55         4740,09
# 774487       1249,55         5161,92
# 774488       1021,14         6501,50
# 774489        641,59         3108,29
#
# [774490 rows x 2 columns]

# %%
df_viagens['Valor diárias'] = df_viagens['Valor diárias'].str.replace(",", ".").astype(float)

# %%
df_viagens['Valor diárias']
# Out:
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4            0.00
#            ...
# 774485    1154.55
# 774486    1154.55
# 774487    1249.55
# 774488    1021.14
# 774489     641.59
# Name: Valor diárias, Length: 774490, dtype: float64

# %%
df_viagens['Valor passagens'] = df_viagens['Valor passagens'].str.replace(",", ".").astype(float)

# %%
df_viagens['Valor passagens']
# Out:
# 0            0.00
# 1            0.00
# 2         2544.74
# 3         4329.72
# 4         7109.73
#            ...
# 774485    4507.09
# 774486    4740.09
# 774487    5161.92
# 774488    6501.50
# 774489    3108.29
# Name: Valor passagens, Length: 774490, dtype: float64

# %%
df_viagens['Valor devolução'] = df_viagens['Valor devolução'].str.replace(",", ".").astype(float)
df_viagens['Valor outros gastos'] = df_viagens['Valor outros gastos'].str.replace(",", ".").astype(float)

# %%
df_viagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774490 entries, 0 to 774489
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  774490 non-null  int64
#  1   Número da Proposta (PCDP)            774490 non-null  object
#  2   Situação                             774490 non-null  object
#  3   Viagem Urgente                       774490 non-null  object
#  4   Justificativa Urgência Viagem        774228 non-null  object
#  5   Código do órgão superior             774490 non-null  int64
#  6   Nome do órgão superior               774490 non-null  object
#  7   Código órgão solicitante             774490 non-null  int64
#  8   Nome órgão solicitante               774490 non-null  object
#  9   CPF viajante                         605451 non-null  object
#  10  Nome                                 774490 non-null  object
# ...

# %%
df_viagens["Valor diárias"] - df_viagens["Valor outros gastos"]
# Out:
# 0            0.00
# 1            0.00
# 2            0.00
# 3        -1240.09
# 4        -1053.53
#            ...
# 774485    1154.55
# 774486    1154.55
# 774487    1249.55
# 774488    1021.14
# 774489     641.59
# Length: 774490, dtype: float64

# %%
df_viagens['Despesas'] = df_viagens['Valor diárias'] + df_viagens['Valor passagens'] + df_viagens['Valor outros gastos']

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  20150776                 060767/25
# 1                                  20261730              000086/25-1C
# 2                                  20286869                 000002/25
# 3                                  20289421                 000001/25
# 4                                  20289650                 000004/25
# ...                                     ...                       ...
# 774485                           2025002373             Sem informaçã
# 774486                           2025002377             Sem informaçã
# 774487                           2025002380             Sem informaçã
# 774488                           2025002397             Sem informaçã
# 774489                           2025002398             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
df_viagens['Cargo'].value_counts()
# Out:
# Cargo
# Informações protegidas por sigilo        110018
# PROFESSOR DO MAGISTERIO SUPERIOR          51045
# PROFESSOR ENS BASICO TECN TECNOLOGICO     38088
# CONTRATADO LEI 8745/93 - NI               18325
# AUDITOR FISCAL FEDERAL AGROPECUARIO       17175
#                                           ...
# PRIMEIRO-SARGENTO                             1
# PROFESSOR DE 1 E 2 GRAU - NS                  1
# ENCARREGADO DE MANUTENCAO                     1
# ASSISTENTE - ASSISTENTE FINANCEIRO            1
# SERVENTE - NA                                 1
# Name: count, Length: 897, dtype: int64

# %%
(df_viagens['Cargo'].value_counts(normalize=True) * 100).rename('Proporção de viagens').reset_index()
# Out:
#                                      Cargo  Proporção de viagens
# 0        Informações protegidas por sigilo             22.523994
# 1         PROFESSOR DO MAGISTERIO SUPERIOR             10.450447
# 2    PROFESSOR ENS BASICO TECN TECNOLOGICO              7.797759
# 3              CONTRATADO LEI 8745/93 - NI              3.751679
# 4      AUDITOR FISCAL FEDERAL AGROPECUARIO              3.516239
# ..                                     ...                   ...
# 892                      PRIMEIRO-SARGENTO              0.000205
# 893           PROFESSOR DE 1 E 2 GRAU - NS              0.000205
# 894              ENCARREGADO DE MANUTENCAO              0.000205
# 895     ASSISTENTE - ASSISTENTE FINANCEIRO              0.000205
# 896                          SERVENTE - NA              0.000205
#
# [897 rows x 2 columns]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# Agrupamento por cargo e soma
df_viagens.groupby("Cargo")['Despesas'].sum().reset_index().sort_values(by="Despesas", ascending=False)
# Out:
#                                       Cargo     Despesas
# 496       Informações protegidas por sigilo 389454950.44
# 633        PROFESSOR DO MAGISTERIO SUPERIOR 112926943.94
# 634   PROFESSOR ENS BASICO TECN TECNOLOGICO  59939819.79
# 759                TECNICO DO SEGURO SOCIAL  48677244.99
# 96                       ANALISTA AMBIENTAL  48009850.71
# ..                                      ...          ...
# 174            ASG - ARTIFICE DE MANUTENCAO         0.00
# 559        OPERADOR DE CENTRAL HIDRELETRICA         0.00
# 456  ESPECIALISTA EM METROLOGIA E QUALIDADE         0.00
# 457   ESPECIALISTA EM PESQ INVEST BIOMEDICA         0.00
# 473                                  FISICO         0.00
#
# [897 rows x 2 columns]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# Agrupamento por Cargo e Média
df_viagens.groupby("Cargo")['Despesas'].mean().reset_index().sort_values(by="Despesas", ascending=False)
# Out:
#                                       Cargo  Despesas
# 578  PAPILOSCOPISTA POLICIAL-SEGUNDA CLASSE  53096.67
# 615                       PRIMEIRO SARGENTO  48803.19
# 694                              SUBTENENTE  33827.47
# 691                        SOLDADO 1 CLASSE  32940.08
# 680                        SEGUNDO SARGENTO  20549.58
# ..                                      ...       ...
# 457   ESPECIALISTA EM PESQ INVEST BIOMEDICA      0.00
# 473                                  FISICO      0.00
# 207              ASSISTENTE DE SECRETARIA I      0.00
# 260  AUXILIAR - AUXILIAR DE SERVICOS GERAIS      0.00
# 880                 TNS-ENGENHEIRO AGRONOMO      0.00
#
# [897 rows x 2 columns]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# Agrupamento por Cargo e Máxima
df_viagens.groupby("Cargo")['Despesas'].max().reset_index().sort_values(by="Despesas", ascending=False)
# Out:
#                                        Cargo  Despesas
# 440  ESP REG DE PET E DER ALC COMB E GAS NAT 245852.80
# 496        Informações protegidas por sigilo 213987.50
# 528              MINISTRO DE PRIMEIRA CLASSE 206166.51
# 842   TECNICO FEDERAL DE FINANCAS E CONTROLE 154259.61
# 694                               SUBTENENTE 143037.50
# ..                                       ...       ...
# 190  ASSISTENTE - ASSISTENTE DE PLANEJAMENTO      0.00
# 473                                   FISICO      0.00
# 207               ASSISTENTE DE SECRETARIA I      0.00
# 232         ATA - TECNICO DE SEG DO TRABALHO      0.00
# 260   AUXILIAR - AUXILIAR DE SERVICOS GERAIS      0.00
#
# [897 rows x 2 columns]

# %%
viagens_por_cargo = (df_viagens['Cargo'].value_counts(normalize=True) * 100).rename('Proporção de viagens').reset_index()

# %%
filtro_mais_de_1_pct = viagens_por_cargo['Proporção de viagens'] > 1

# %%
viagens_por_cargo[filtro_mais_de_1_pct]
# Out:
#                                        Cargo  Proporção de viagens
# 0          Informações protegidas por sigilo                 22.52
# 1           PROFESSOR DO MAGISTERIO SUPERIOR                 10.45
# 2      PROFESSOR ENS BASICO TECN TECNOLOGICO                  7.80
# 3                CONTRATADO LEI 8745/93 - NI                  3.75
# 4        AUDITOR FISCAL FEDERAL AGROPECUARIO                  3.52
# 5                         ANALISTA AMBIENTAL                  3.30
# 6                ASSISTENTE EM ADMINISTRAçãO                  2.22
# 7                   TECNICO DO SEGURO SOCIAL                  2.00
# 8   AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL                  1.86
# 9     ANALISTA TRIBUTARIO REC FEDERAL BRASIL                  1.74
# 10   TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  1.67
# 11                                 MOTORISTA                  1.30
# 12                AUDITOR FISCAL DO TRABALHO                  1.23
# ...

# %%
filtro_eh_professor = viagens_por_cargo['Cargo'].str.startswith('PROFESSOR')

# %%
viagens_por_cargo[filtro_eh_professor]
# Out:
#                                         Cargo  Proporção de viagens
# 1            PROFESSOR DO MAGISTERIO SUPERIOR                 10.45
# 2       PROFESSOR ENS BASICO TECN TECNOLOGICO                  7.80
# 78   PROFESSOR MAGISTERIO SUPERIOR-SUBSTITUTO                  0.16
# 151   PROFESSOR MAGISTERIO SUPERIOR-VISITANTE                  0.05
# 202       PROFESSOR TIT-LIVRE MAGIST SUPERIOR                  0.03
# 239                  PROFESSOR DE 1 GRAU - NI                  0.02
# 561                  PROFESSOR DE 1 GRAU - NS                  0.00
# 584                  PROFESSOR DE 1 E 2 GRAUS                  0.00
# 652        PROFESSOR REGENTE DE ENSINO I - NI                  0.00
# 672               PROFESSOR 3 GRAU SUBSTITUTO                  0.00
# 742                   PROFESSOR - EX - TERRIT                  0.00
# 778  PROFESSOR MAGISTERIO SUPERIOR-TEMPORARIO                  0.00
# 824                PROFESSOR 1 A 4 SERIE - NI                  0.00
# ...

# %%
viagens_por_cargo[filtro_eh_professor & filtro_mais_de_1_pct]
# Out:
#                                    Cargo  Proporção de viagens
# 1       PROFESSOR DO MAGISTERIO SUPERIOR                 10.45
# 2  PROFESSOR ENS BASICO TECN TECNOLOGICO                  7.80

# %%
gastos_totais_por_cargo = df_viagens.groupby('Cargo')['Despesas'].sum().reset_index()

# %%
gastos_totais_por_cargo[gastos_totais_por_cargo['Despesas'] > 10000000]
# Out:
#                                         Cargo     Despesas
# 19                      AGENTE ADMINISTRATIVO  15919315.18
# 96                         ANALISTA AMBIENTAL  48009850.71
# 116                 ANALISTA DO SEGURO SOCIAL  12353486.26
# 127    ANALISTA INFRA-ESTRUTURA DE TRANSPORTE  10767236.60
# 135    ANALISTA TRIBUTARIO REC FEDERAL BRASIL  16892539.98
# 210               ASSISTENTE EM ADMINISTRAçãO  16333163.17
# 245       AUDITOR FISCAL FEDERAL AGROPECUARIO  25260344.82
# 246  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL  26584710.05
# 356               CONTRATADO LEI 8745/93 - NI  14156211.00
# 435     ESP EM REG DE SERV PUB DE TELECOMUNIC  11227853.17
# 436         ESP EM REGULACAO DE AVIACAO CIVIL  10115882.76
# 439   ESP EM REGULACAO E VIGILANCIA SANITARIA  25510535.49
# 441  ESP. EM POL. PUBL. E GESTAO GOVERNAMENTA  10161495.90
# 496         Informações protegidas por sigilo 389454950.44
# 528               MINISTRO DE PRIMEIRA CLASSE  10852436.25
# ...

# %%
# Despesas médias por cargo
gastos_medio_por_cargo = df_viagens.groupby('Cargo')['Despesas'].mean().reset_index()

# %%
gastos_medio_por_cargo[gastos_medio_por_cargo['Despesas'] > 10_000]
# Out:
#                                        Cargo  Despesas
# 40       AGENTE DE POLICIA - CLASSE ESPECIAL  15153.00
# 99             ANALISTA DE COMERCIO EXTERIOR  10354.53
# 170                ARTIFICE DE MECANICA - NI  17630.73
# 203                ASSISTENTE DE CHANCELARIA  10186.05
# 272                AUXILIAR DE CONTABILIDADE  12031.39
# 298            AUXILIAR DE SERVICOS DIVERSOS  19884.06
# 312            AUXILIAR NM - 10 (DEC JUD-ME)  11568.69
# 348                              CONSELHEIRO  10484.06
# 351                               CONTADOR I  11271.42
# 387                 DIRETOR DO BANCO CENTRAL  10953.14
# 439  ESP EM REGULACAO E VIGILANCIA SANITARIA  13511.94
# 528              MINISTRO DE PRIMEIRA CLASSE  17280.95
# 529               MINISTRO DE SEGUNDA CLASSE  12720.35
# 549                   OFICIAL DE CHANCELARIA  10960.19
# 578   PAPILOSCOPISTA POLICIAL-SEGUNDA CLASSE  53096.67
# 614              PRESIDENTE DO BANCO CENTRAL  10665.21
# ...

# %%
# Contagem de cargos nulos
df_viagens['Cargo'].value_counts(dropna=False)
# Out:
# Cargo
# NaN                                      286042
# Informações protegidas por sigilo        110018
# PROFESSOR DO MAGISTERIO SUPERIOR          51045
# PROFESSOR ENS BASICO TECN TECNOLOGICO     38088
# CONTRATADO LEI 8745/93 - NI               18325
#                                           ...
# CARTOGRAFO                                    1
# MEDICO - PEC-PF                               1
# PRIMEIRO-SARGENTO                             1
# ESPEC DESENV DE SOFTWARE - 40H                1
# TECNICO ADMINISTRATIVO E OPERACIONAL          1
# Name: count, Length: 898, dtype: int64

# %%
# Trocar o valor NaN em toda tabela
df_viagens.fillna("Não Identificado")
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  20150776                 060767/25
# 1                                  20261730              000086/25-1C
# 2                                  20286869                 000002/25
# 3                                  20289421                 000001/25
# 4                                  20289650                 000004/25
# ...                                     ...                       ...
# 774485                           2025002373             Sem informaçã
# 774486                           2025002377             Sem informaçã
# 774487                           2025002380             Sem informaçã
# 774488                           2025002397             Sem informaçã
# 774489                           2025002398             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
# Trocar o valor NaN da coluna "Cargo"
df_viagens['Cargo'] = df_viagens['Cargo'].fillna("Não Identificado")

# %%
# Excluir as linhas NULL na coluna cargo
df_viagens.dropna(subset='Cargo')
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  20150776                 060767/25
# 1                                  20261730              000086/25-1C
# 2                                  20286869                 000002/25
# 3                                  20289421                 000001/25
# 4                                  20289650                 000004/25
# ...                                     ...                       ...
# 774485                           2025002373             Sem informaçã
# 774486                           2025002377             Sem informaçã
# 774487                           2025002380             Sem informaçã
# 774488                           2025002397             Sem informaçã
# 774489                           2025002398             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
df_viagens[["Período - Data de início", "Período - Data de fim"]]
# Out:
#        Período - Data de início Período - Data de fim
# 0                    29/09/2025            30/10/2025
# 1                    01/03/2025            04/08/2025
# 2                    25/01/2025            01/02/2025
# 3                    05/01/2025            07/01/2025
# 4                    04/01/2025            06/01/2025
# ...                         ...                   ...
# 774485               23/11/2025            24/11/2025
# 774486               18/11/2025            19/11/2025
# 774487               19/11/2025            20/11/2025
# 774488               24/11/2025            26/11/2025
# 774489               25/11/2025            26/11/2025
#
# [774490 rows x 2 columns]

# %%
pd.to_datetime(df_viagens["Período - Data de início"], format="%d/%m/%Y")
# Out:
# 0        2025-09-29
# 1        2025-03-01
# 2        2025-01-25
# 3        2025-01-05
# 4        2025-01-04
#             ...
# 774485   2025-11-23
# 774486   2025-11-18
# 774487   2025-11-19
# 774488   2025-11-24
# 774489   2025-11-25
# Name: Período - Data de início, Length: 774490, dtype: datetime64[ns]

# %%
df_viagens["Período - Data de início"] = pd.to_datetime(df_viagens["Período - Data de início"], format="%d/%m/%Y")
df_viagens["Período - Data de fim"] = pd.to_datetime(df_viagens["Período - Data de fim"], format="%d/%m/%Y")

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  20150776                 060767/25
# 1                                  20261730              000086/25-1C
# 2                                  20286869                 000002/25
# 3                                  20289421                 000001/25
# 4                                  20289650                 000004/25
# ...                                     ...                       ...
# 774485                           2025002373             Sem informaçã
# 774486                           2025002377             Sem informaçã
# 774487                           2025002380             Sem informaçã
# 774488                           2025002397             Sem informaçã
# 774489                           2025002398             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
df_viagens['Período - Data de início'].dt.month_name()
# Out:
# 0         September
# 1             March
# 2           January
# 3           January
# 4           January
#             ...
# 774485     November
# 774486     November
# 774487     November
# 774488     November
# 774489     November
# Name: Período - Data de início, Length: 774490, dtype: object

# %%
# Criando a coluna "Mês da Viagem"
df_viagens['Mês da viagem'] = df_viagens['Período - Data de início'].dt.month_name()

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  20150776                 060767/25
# 1                                  20261730              000086/25-1C
# 2                                  20286869                 000002/25
# 3                                  20289421                 000001/25
# 4                                  20289650                 000004/25
# ...                                     ...                       ...
# 774485                           2025002373             Sem informaçã
# 774486                           2025002377             Sem informaçã
# 774487                           2025002380             Sem informaçã
# 774488                           2025002397             Sem informaçã
# 774489                           2025002398             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
# Criação de nova coluna " Dias de viagem" que retorna de dias da viagem em valor numérico.
df_viagens['Dias de viagem'] = (df_viagens["Período - Data de fim"] - df_viagens["Período - Data de início"]).dt.days

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  20150776                 060767/25
# 1                                  20261730              000086/25-1C
# 2                                  20286869                 000002/25
# 3                                  20289421                 000001/25
# 4                                  20289650                 000004/25
# ...                                     ...                       ...
# 774485                           2025002373             Sem informaçã
# 774486                           2025002377             Sem informaçã
# 774487                           2025002380             Sem informaçã
# 774488                           2025002397             Sem informaçã
# 774489                           2025002398             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
# Contrução de coluna e agregação com mais de 1 coluna
df_viagens.groupby('Cargo').agg(despesa_media = ('Despesas', 'mean'))
# Out:
#                                     despesa_media
# Cargo
# AAD - AUXILIAR DE RECURSOS HUMANOS        4934.46
# AAD-AUX DE RECURSOS MATERIAIS              633.50
# AAD-AUXILIAR ADMINISTRATIVO                268.31
# AAD-AUXILIAR DE INFORMATICA                595.00
# AAD-AUXILIAR DE OPERACOES                  992.06
# ...                                           ...
# VIGILANTE                                  819.53
# VIGILANTE - NI                            6821.34
# VISITADOR SANITARIO                       2110.53
# ZOOTECNISTA                                858.86
# ZOOTECNISTA - NS                          1113.59
#
# [898 rows x 1 columns]

# %%
# Agragando por cargo Colunas diferente com medidas diferentes
df_viagens.groupby('Cargo').agg(despesa_media = ('Despesas', 'mean'), duracao_media=('Dias de viagem', 'mean'))
# Out:
#                                     despesa_media  duracao_media
# Cargo
# AAD - AUXILIAR DE RECURSOS HUMANOS        4934.46           4.00
# AAD-AUX DE RECURSOS MATERIAIS              633.50           4.00
# AAD-AUXILIAR ADMINISTRATIVO                268.31           2.10
# AAD-AUXILIAR DE INFORMATICA                595.00           3.50
# AAD-AUXILIAR DE OPERACOES                  992.06           5.65
# ...                                           ...            ...
# VIGILANTE                                  819.53           1.71
# VIGILANTE - NI                            6821.34          20.53
# VISITADOR SANITARIO                       2110.53           3.97
# ZOOTECNISTA                                858.86           1.60
# ZOOTECNISTA - NS                          1113.59           3.36
#
# [898 rows x 2 columns]

# %%
(
    df_viagens
    .groupby('Cargo')
    .agg(
        despesa_media = ('Despesas', 'mean'),
        duracao_media=('Dias de viagem', 'mean'),
        despesas_totais = ('Despesas', 'sum'),
        destino_mais_frequente=("Destinos", pd.Series.mode),  # Modo de trazer a Moda no pandas
        n_viagens = ('Nome', 'count')
        )
    .reset_index()
    )
# Out:
#                                   Cargo  despesa_media  duracao_media  \
# 0    AAD - AUXILIAR DE RECURSOS HUMANOS        4934.46           4.00
# 1         AAD-AUX DE RECURSOS MATERIAIS         633.50           4.00
# 2           AAD-AUXILIAR ADMINISTRATIVO         268.31           2.10
# 3           AAD-AUXILIAR DE INFORMATICA         595.00           3.50
# 4             AAD-AUXILIAR DE OPERACOES         992.06           5.65
# ..                                  ...            ...            ...
# 893                           VIGILANTE         819.53           1.71
# 894                      VIGILANTE - NI        6821.34          20.53
# 895                 VISITADOR SANITARIO        2110.53           3.97
# 896                         ZOOTECNISTA         858.86           1.60
# 897                    ZOOTECNISTA - NS        1113.59           3.36
#
#      despesas_totais                             destino_mais_frequente  \
# ...

# %%
# filtro da tabela agregada, quantitativo de proporção de cargo por viagem
df_cargos = df_viagens['Cargo'].value_counts(normalize=True).reset_index()
df_cargos
# Out:
#                                      Cargo  proportion
# 0                         Não Identificado        0.37
# 1        Informações protegidas por sigilo        0.14
# 2         PROFESSOR DO MAGISTERIO SUPERIOR        0.07
# 3    PROFESSOR ENS BASICO TECN TECNOLOGICO        0.05
# 4              CONTRATADO LEI 8745/93 - NI        0.02
# ..                                     ...         ...
# 893                             CARTOGRAFO        0.00
# 894                        MEDICO - PEC-PF        0.00
# 895                      PRIMEIRO-SARGENTO        0.00
# 896         ESPEC DESENV DE SOFTWARE - 40H        0.00
# 897   TECNICO ADMINISTRATIVO E OPERACIONAL        0.00
#
# [898 rows x 2 columns]

# %%
df_cargos.loc[df_cargos['proportion'] > 0.01, 'Cargo']
# Out:
# 0                             Não Identificado
# 1            Informações protegidas por sigilo
# 2             PROFESSOR DO MAGISTERIO SUPERIOR
# 3        PROFESSOR ENS BASICO TECN TECNOLOGICO
# 4                  CONTRATADO LEI 8745/93 - NI
# 5          AUDITOR FISCAL FEDERAL AGROPECUARIO
# 6                           ANALISTA AMBIENTAL
# 7                  ASSISTENTE EM ADMINISTRAçãO
# 8                     TECNICO DO SEGURO SOCIAL
# 9     AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL
# 10      ANALISTA TRIBUTARIO REC FEDERAL BRASIL
# 11     TECNICO INFOR GEOGRAFICAS E ESTATISTICA
# Name: Cargo, dtype: object

# %%
df_viagens_consolidado = (
    df_viagens
    .groupby('Cargo')
    .agg(
        despesa_media = ('Despesas', 'mean'),
        duracao_media=('Dias de viagem', 'mean'),
        despesas_totais = ('Despesas', 'sum'),
        destino_mais_frequente=("Destinos", pd.Series.mode),  # Modo de trazer a Moda no pandas
        n_viagens = ('Nome', 'count')
        )
    .reset_index()
    .sort_values(by='despesas_totais', ascending=False)
    )

# %%
cargos_relevantes = df_cargos.loc[df_cargos['proportion'] > 0.01, 'Cargo']

# %%
filtro = df_viagens_consolidado['Cargo'].isin(cargos_relevantes)

# %%
df_final = df_viagens_consolidado[filtro]

# %%
df_final
# Out:
#                                         Cargo  despesa_media  duracao_media  \
# 545                          Não Identificado        3811.37           7.55
# 496         Informações protegidas por sigilo        3539.92           7.45
# 634          PROFESSOR DO MAGISTERIO SUPERIOR        2212.30           3.53
# 635     PROFESSOR ENS BASICO TECN TECNOLOGICO        1573.72           2.31
# 760                  TECNICO DO SEGURO SOCIAL        4991.00          12.16
# 96                         ANALISTA AMBIENTAL        2982.16           5.43
# 246  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL        2925.90           2.98
# 245       AUDITOR FISCAL FEDERAL AGROPECUARIO        1470.76           1.95
# 135    ANALISTA TRIBUTARIO REC FEDERAL BRASIL        1988.76           3.31
# 210               ASSISTENTE EM ADMINISTRAçãO        1507.86           2.17
# 356               CONTRATADO LEI 8745/93 - NI         772.51           2.10
# ...

# %%
df_final.plot(x="Cargo", y="n_viagens", kind="bar")
# Out:
# <Axes: xlabel='Cargo'>

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(16,6))

ax.barh(df_final['Cargo'], df_final['n_viagens'], color="#49deac")
ax.invert_yaxis()
ax.set_facecolor('#3b3b47')

fig.suptitle('Viagens por Cargo Público (2025)')

plt.figtext(0.79, 0.90,'Fonte: Portal da Transparência', fontsize=8)

plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.yticks(fontsize = 8)

plt.xlabel('Número de viagens')
plt.show()

# %%
# Criando a figura
fig, ax = plt.subplots(figsize=(16,6))

# Plotando o gráfico
ax.barh(df_final['Cargo'], df_final['despesa_media'], color="#49deac")
ax.invert_yaxis()

# Ajustando o gráfico
ax.set_facecolor('#3b3b47')
fig.suptitle('Despesa média em viagens por cargo Público (2025)')
plt.figtext(0.79, 0.90,'Fonte: Portal da Transparência', fontsize=8)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.yticks(fontsize = 8)
plt.xlabel('Despesa média')

# Exibindo o gráfico
plt.show()

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  20150776                 060767/25
# 1                                  20261730              000086/25-1C
# 2                                  20286869                 000002/25
# 3                                  20289421                 000001/25
# 4                                  20289650                 000004/25
# ...                                     ...                       ...
# 774485                           2025002373             Sem informaçã
# 774486                           2025002377             Sem informaçã
# 774487                           2025002380             Sem informaçã
# 774488                           2025002397             Sem informaçã
# 774489                           2025002398             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %%
fig, ax = plt.subplots(figsize=(16,6))

ax.scatter(df_viagens['Dias de viagem'], df_viagens['Despesas'])

# %%
#df_viagens['Despesas'] > 200_000

# Contagem de Viagens acima de 200.000
(df_viagens['Despesas'] > 200_000).value_counts()

# %%
caminho_dados_passagens = "/content/drive/MyDrive/AD/2025_Passagem.csv"

# %%
df_passagens = pd.read_csv(caminho_dados_passagens, encoding='Windows-1252', sep=';', decimal=',')
df_passagens

# %%
# Combinar 2 tabelas no Python com colunas de mesmo nome.
df_viagens.merge(df_passagens)

# %%
caminho_saida = "/content/drive/MyDrive/AD/output/tabela_passa_viagem.xlsx"

# %%
# Salvar tabela e converte para excel c/ indice
#df_final.to_excel(caminho_saida)

# Sem indice
df_final.to_excel(caminho_saida, index=False)

# Converter em CSV
# df_final.to_csv()
